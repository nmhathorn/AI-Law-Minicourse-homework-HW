# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import collections
import math
import os
import random
from tempfile import gettempdir
import zipfile

import numpy as np
from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf

# Step 1: Download the data.
url = 'http://mattmahoney.net/dc/'


# pylint: disable=redefined-outer-name
def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  local_filename = os.path.join(gettempdir(), filename)
  if not os.path.exists(local_filename):
    local_filename, _ = urllib.request.urlretrieve(url + filename,
                                                   local_filename)
  statinfo = os.stat(local_filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified', filename)
  else:
    print(statinfo.st_size)
    raise Exception('Failed to verify ' + local_filename +
                    '. Can you get to it with a browser?')
  return local_filename


filename = maybe_download('text8.zip', 31344016)


# Read the data into a list of strings.
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words."""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data

vocabulary = read_data(filename)
print('Data size', len(vocabulary))

# Step 2: Build the dictionary and replace rare words with UNK token.
vocabulary_size = 50000


def build_dataset(words, n_words):
  """Process raw inputs into a dataset."""
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(n_words - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    index = dictionary.get(word, 0)
    if index == 0:  # dictionary['UNK']
      unk_count += 1
    data.append(index)
  count[0][1] = unk_count
  reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
  return data, count, dictionary, reversed_dictionary

# Filling 4 global variables:
# data - list of codes (integers from 0 to vocabulary_size-1).
#   This is the original text but words are replaced by their codes
# count - map of words(strings) to count of occurrences
# dictionary - map of words(strings) to their codes(integers)
# reverse_dictionary - maps codes(integers) to words(strings)
data, count, dictionary, reverse_dictionary = build_dataset(vocabulary,
                                                            vocabulary_size)
del vocabulary  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])

data_index = 0

# Step 3: Function to generate a training batch for the skip-gram model.
def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1  # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  if data_index + span > len(data):
    data_index = 0
  buffer.extend(data[data_index:data_index + span])
  data_index += span
  for i in range(batch_size // num_skips):
    context_words = [w for w in range(span) if w != skip_window]
    words_to_use = random.sample(context_words, num_skips)
    for j, context_word in enumerate(words_to_use):
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[context_word]
    if data_index == len(data):
      buffer[:] = data[:span]
      data_index = span
    else:
      buffer.append(data[data_index])
      data_index += 1
  # Backtrack a little bit to avoid skipping words in the end of a batch
  data_index = (data_index + len(data) - span) % len(data)
  return batch, labels

batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
  print(batch[i], reverse_dictionary[batch[i]],
        '->', labels[i, 0], reverse_dictionary[labels[i, 0]])

# Step 4: Build and train a skip-gram model.

batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1       # How many words to consider left and right.
num_skips = 2         # How many times to reuse an input to generate a label.
num_sampled = 64      # Number of negative examples to sample.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. These 3 variables are used only for
# displaying model accuracy, they don't affect calculation.
valid_size = 16     # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)


graph = tf.Graph()

with graph.as_default():

  # Input data.
  train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

  # Ops and variables pinned to the CPU because of missing GPU implementation
  with tf.device('/cpu:0'):
    # Look up embeddings for inputs.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    embed = tf.nn.embedding_lookup(embeddings, train_inputs)

    # Construct the variables for the NCE loss
    nce_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

  # Compute the average NCE loss for the batch.
  # tf.nce_loss automatically draws a new sample of the negative labels each
  # time we evaluate the loss.
  # Explanation of the meaning of NCE loss:
  #   http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/
  loss = tf.reduce_mean(
      tf.nn.nce_loss(weights=nce_weights,
                     biases=nce_biases,
                     labels=train_labels,
                     inputs=embed,
                     num_sampled=num_sampled,
                     num_classes=vocabulary_size))

  # Construct the SGD optimizer using a learning rate of 1.0.
  optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

  # Compute the cosine similarity between minibatch examples and all embeddings.
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
      normalized_embeddings, valid_dataset)
  similarity = tf.matmul(
      valid_embeddings, normalized_embeddings, transpose_b=True)

  # Add variable initializer.
  init = tf.global_variables_initializer()

# Step 5: Begin training.
num_steps = 100001

with tf.Session(graph=graph) as session:
  # We must initialize all variables before we use them.
  init.run()
  print('Initialized')

  average_loss = 0
  for step in xrange(num_steps):
    batch_inputs, batch_labels = generate_batch(
        batch_size, num_skips, skip_window)
    feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

    # We perform one update step by evaluating the optimizer op (including it
    # in the list of returned values for session.run()
    _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += loss_val

    if step % 2000 == 0:
      if step > 0:
        average_loss /= 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step ', step, ': ', average_loss)
      average_loss = 0

    # Note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8  # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k + 1]
        log_str = 'Nearest to %s:' % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log_str = '%s %s,' % (log_str, close_word)
        print(log_str)
  final_embeddings = normalized_embeddings.eval()

# Step 6: Visualize the embeddings.


# pylint: disable=missing-docstring
# Function to draw visualization of distance between embeddings.
def plot_with_labels(low_dim_embs, labels, filename):
  assert low_dim_embs.shape[0] >= len(labels), 'More labels than embeddings'
  plt.figure(figsize=(18, 18))  # in inches
  for i, label in enumerate(labels):
    x, y = low_dim_embs[i, :]
    plt.scatter(x, y)
    plt.annotate(label,
                 xy=(x, y),
                 xytext=(5, 2),
                 textcoords='offset points',
                 ha='right',
                 va='bottom')

  plt.savefig(filename)


# pylint: disable=g-import-not-at-top
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
plot_only = 500
low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
labels = [reverse_dictionary[i] for i in xrange(plot_only)]
plot_with_labels(low_dim_embs, labels, os.path.join(gettempdir(), 'tsne.png'))
# Out:
# Found and verified text8.zip
# Data size 17005207
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5235, 3084, 12, 6, 195, 2, 3136, 46, 59, 156] ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']
# 3084 originated -> 5235 anarchism
# 3084 originated -> 12 as
# 12 as -> 6 a
# 12 as -> 3084 originated
# 6 a -> 195 term
# 6 a -> 12 as
# 195 term -> 6 a
# 195 term -> 2 of
# Initialized
# Average loss at step  0 :  313.68621826171875
# Nearest to this: muad, constraint, jadwiga, wallenberg, kosrae, crescent, quarrel, pasteur,
# Nearest to such: nouveau, mating, quarried, publication, yd, mactutor, interacts, kernighan,
# Nearest to on: phrases, danzig, overpopulation, examined, fronti, foodborne, poz, aeneid,
# Nearest to an: alpina, choirs, astrologers, transcend, penn, continues, rethinking, hci,
# Nearest to will: implicitly, streetcar, wend, looters, ventricular, goodnight, trait, seduced,
# Nearest to i: chefs, working, valor, assesses, plenty, deep, mouvement, mazzola,
# Nearest to was: petsamo, encyclical, improvement, wallis, midwest, hasse, iliad, julio,
# Nearest to at: superfluous, comerica, awareness, explorer, advent, nantucket, destitute, preaching,
# Nearest to state: afghan, garrisoned, regio, cystitis, suffers, pruitt, contacting, dreamers,
# Nearest to had: haemophilia, broncos, connotations, dwt, ratios, trusts, overthrowing, offices,
# Nearest to three: nsh, ascetics, proviso, witnesses, griff, rriais, militaries, licit,
# Nearest to no: boar, florentine, proclus, oxide, inverse, belt, neman, daimler,
# Nearest to into: mourner, runoff, storehouses, lmi, bandy, conf, rhus, cremated,
# Nearest to as: socialized, maniac, assad, cabinets, skier, hardships, dignified, zechariah,
# Nearest to four: acme, apologies, scorned, monopolies, jessica, tsvetaeva, eof, cameo,
# Nearest to zero: ecole, fielded, graduating, certify, travelogue, trope, northwards, nationalist,
# Average loss at step  2000 :  113.45563807964325
# Average loss at step  4000 :  52.231579123020175
# Average loss at step  6000 :  33.56864387714863
# Average loss at step  8000 :  23.56221581554413
# Average loss at step  10000 :  17.926541990995407
# Nearest to this: orthodox, blore, the, alfons, tar, atomic, place, andrews,
# Nearest to such: well, hebrew, alcohols, pilots, lnot, calculi, waterloo, derivative,
# Nearest to on: in, and, from, fao, with, cocaine, when, at,
# Nearest to an: alpina, the, continues, brain, out, months, penn, id,
# Nearest to will: looters, implicitly, absent, introduced, acts, trait, republics, philo,
# Nearest to i: working, s, who, chefs, plenty, styles, deep, especially,
# Nearest to was: is, and, in, suffered, unarable, were, s, stop,
# Nearest to at: mosque, from, fertilizers, and, explorer, on, awareness, prosecution,
# Nearest to state: afghan, austin, archie, complications, refrigerator, garrisoned, rocky, groups,
# Nearest to had: offices, period, swimmer, chance, removed, ratios, tb, bligh,
# Nearest to three: nine, one, zero, four, two, gb, agave, archie,
# Nearest to no: belt, oxide, coke, gb, daimler, shut, relation, employers,
# Nearest to into: as, rhus, with, shoe, narratives, runoff, avicenna, heads,
# Nearest to as: and, into, dancing, determination, is, trojan, fao, drawings,
# Nearest to four: eight, six, zero, reginae, nine, haart, agave, archie,
# Nearest to zero: nine, archie, six, eight, agave, seven, one, reginae,
# Average loss at step  12000 :  14.017540182948112
# Average loss at step  14000 :  11.957602931857108
# Average loss at step  16000 :  9.997644699931145
# Average loss at step  18000 :  8.431082450866699
# Average loss at step  20000 :  8.059399729847907
# Nearest to this: the, alfons, circ, agouti, its, orthodox, an, a,
# Nearest to such: well, alcohols, hebrew, nouveau, dasyprocta, pilots, waterloo, lnot,
# Nearest to on: in, and, from, at, with, dasyprocta, meridians, of,
# Nearest to an: the, this, dasyprocta, alpina, warning, continues, their, terminal,
# Nearest to will: looters, absent, trait, apollodorus, eurydice, philo, agouti, hbox,
# Nearest to i: working, who, UNK, s, enigma, nsted, classically, plenty,
# Nearest to was: is, were, has, by, in, agouti, had, as,
# Nearest to at: in, and, on, mosque, from, circ, of, dasyprocta,
# Nearest to state: afghan, circ, austin, gollancz, archie, complications, garrisoned, rocky,
# Nearest to had: was, has, is, agouti, offices, are, removed, djs,
# Nearest to three: nine, four, two, zero, circ, seven, eight, dasyprocta,
# Nearest to no: a, belt, hbox, dasyprocta, coke, daimler, firing, oxide,
# Nearest to into: as, with, from, runoff, and, dasyprocta, for, on,
# Nearest to as: and, dasyprocta, is, into, for, hbox, was, in,
# Nearest to four: eight, six, nine, zero, seven, two, three, circ,
# Nearest to zero: nine, eight, six, seven, four, five, circ, three,
# Average loss at step  22000 :  7.089275554537773
# Average loss at step  24000 :  6.817529947638512
# Average loss at step  26000 :  6.739335612773895
# Average loss at step  28000 :  6.371192127466202
# Average loss at step  30000 :  5.910185408592224
# Nearest to this: the, which, it, circ, its, agouti, alfons, dasyprocta,
# Nearest to such: well, alcohols, hebrew, dasyprocta, nouveau, calculi, priority, lnot,
# Nearest to on: in, from, at, and, dasyprocta, for, fao, by,
# Nearest to an: this, the, carolla, dasyprocta, their, terminal, warning, id,
# Nearest to will: would, can, looters, absent, might, eurydice, philo, trait,
# Nearest to i: chefs, who, working, UNK, ramps, plenty, four, six,
# Nearest to was: is, were, has, had, by, selects, agouti, numa,
# Nearest to at: in, and, from, on, for, circ, dasyprocta, agouti,
# Nearest to state: afghan, circ, garrisoned, gollancz, complications, archie, wideawake, esdras,
# Nearest to had: has, was, have, were, agouti, are, is, removed,
# Nearest to three: four, five, six, eight, two, seven, nine, zero,
# Nearest to no: a, belt, hbox, firing, daimler, difranco, dasyprocta, coke,
# Nearest to into: with, from, in, as, and, on, abet, birkenau,
# Nearest to as: dasyprocta, and, hbox, by, in, amalthea, for, abet,
# Nearest to four: eight, six, five, seven, three, nine, two, zero,
# Nearest to zero: six, eight, five, seven, nine, four, circ, three,
# Average loss at step  32000 :  5.9615595350265504
# Average loss at step  34000 :  5.647733661293984
# Average loss at step  36000 :  5.7418449165821075
# Average loss at step  38000 :  5.486529697775841
# Average loss at step  40000 :  5.252307041406631
# Nearest to this: the, which, it, circ, that, agouti, its, morita,
# Nearest to such: well, alcohols, nouveau, hebrew, priority, calculi, dasyprocta, lnot,
# Nearest to on: in, at, from, meridians, dasyprocta, and, two, fao,
# Nearest to an: carolla, the, terminal, this, aveiro, dasyprocta, warning, astrologers,
# Nearest to will: can, would, might, looters, may, could, absent, eurydice,
# Nearest to i: chefs, who, UNK, working, you, nsted, jp, plenty,
# Nearest to was: is, were, has, had, by, selects, numa, are,
# Nearest to at: in, on, from, for, circ, and, dasyprocta, agouti,
# Nearest to state: afghan, garrisoned, circ, archie, gollancz, wideawake, monroe, agouti,
# Nearest to had: has, was, have, were, agouti, djs, aquarius, are,
# Nearest to three: four, six, five, eight, two, seven, zero, one,
# Nearest to no: a, neman, hbox, belt, coke, daimler, difranco, firing,
# Nearest to into: from, with, albury, in, as, and, dim, birkenau,
# Nearest to as: vma, dasyprocta, hbox, albury, amalthea, by, abet, and,
# Nearest to four: six, eight, five, three, seven, zero, two, nine,
# Nearest to zero: eight, six, seven, four, five, nine, three, circ,
# Average loss at step  42000 :  5.376630071401596
# Average loss at step  44000 :  5.231918665289879
# Average loss at step  46000 :  5.255522423863411
# Average loss at step  48000 :  5.2240589787960054
# Average loss at step  50000 :  4.978308026075363
# Nearest to this: which, it, the, that, circ, another, its, agouti,
# Nearest to such: well, alcohols, priority, kapoor, nouveau, calculi, hebrew, known,
# Nearest to on: in, at, from, two, dasyprocta, meridians, fao, circ,
# Nearest to an: carolla, terminal, the, aveiro, this, dasyprocta, quelled, id,
# Nearest to will: can, would, could, may, might, looters, to, absent,
# Nearest to i: chefs, you, who, jp, four, working, nsted, UNK,
# Nearest to was: is, were, has, had, by, selects, agouti, are,
# Nearest to at: in, on, from, agouti, and, three, circ, dasyprocta,
# Nearest to state: airtight, afghan, garrisoned, circ, monroe, gollancz, archie, complications,
# Nearest to had: has, have, was, were, djs, been, aquarius, agouti,
# Nearest to three: four, five, six, two, seven, eight, circ, one,
# Nearest to no: a, hbox, neman, daimler, firing, cairo, difranco, flooding,
# Nearest to into: from, with, albury, in, on, and, as, birkenau,
# Nearest to as: vma, dasyprocta, abet, albury, hbox, by, amalthea, for,
# Nearest to four: six, five, three, eight, two, seven, one, circ,
# Nearest to zero: eight, six, seven, five, nine, four, circ, three,
# Average loss at step  52000 :  5.031263549804687
# Average loss at step  54000 :  5.175242365598678
# Average loss at step  56000 :  5.041370417237282
# Average loss at step  58000 :  5.061012272715568
# Average loss at step  60000 :  4.942797385573387
# Nearest to this: which, it, that, the, circ, morita, another, one,
# Nearest to such: well, alcohols, priority, these, known, kapoor, nouveau, calculi,
# Nearest to on: in, from, at, meridians, during, fao, dasyprocta, circ,
# Nearest to an: terminal, carolla, this, quelled, aveiro, astrologers, dasyprocta, alaskans,
# Nearest to will: would, can, could, may, might, should, looters, absent,
# Nearest to i: chefs, you, who, jp, ursus, chlamydia, t, working,
# Nearest to was: is, were, has, had, by, been, became, be,
# Nearest to at: in, on, agouti, from, dasyprocta, circ, ursus, for,
# Nearest to state: airtight, afghan, garrisoned, circ, ursus, archie, gollancz, kapoor,
# Nearest to had: has, have, was, were, djs, agouti, aquarius, been,
# Nearest to three: five, four, six, two, eight, seven, circ, one,
# Nearest to no: a, hbox, neman, daimler, cairo, campy, difranco, pulau,
# Nearest to into: from, albury, with, in, on, through, within, under,
# Nearest to as: vma, albury, dasyprocta, hbox, abet, amalthea, in, and,
# Nearest to four: five, six, eight, three, seven, nine, two, circ,
# Nearest to zero: eight, six, five, seven, nine, four, circ, three,
# Average loss at step  62000 :  5.0202590545415875
# Average loss at step  64000 :  4.845454109191895
# Average loss at step  66000 :  4.595892305493355
# Average loss at step  68000 :  4.993372702002525
# Average loss at step  70000 :  4.883136142730713
# Nearest to this: which, it, the, that, morita, circ, raises, one,
# Nearest to such: well, alcohols, these, priority, known, calculi, nouveau, many,
# Nearest to on: in, from, upon, at, dasyprocta, and, during, circ,
# Nearest to an: terminal, quelled, carolla, the, aveiro, voted, replicas, alaskans,
# Nearest to will: would, can, could, may, might, should, looters, mico,
# Nearest to i: chefs, you, who, jp, thaler, UNK, t, chlamydia,
# Nearest to was: is, were, has, had, when, became, by, agouti,
# Nearest to at: in, on, for, dasyprocta, circ, agouti, and, mukherjee,
# Nearest to state: garrisoned, airtight, cebus, circ, afghan, gollancz, archie, ursus,
# Nearest to had: has, have, was, were, aquarius, mico, djs, thaler,
# Nearest to three: six, four, five, two, eight, seven, circ, nine,
# Nearest to no: a, hbox, neman, daimler, difranco, cairo, coke, pulau,
# Nearest to into: from, albury, with, through, under, on, within, in,
# Nearest to as: vma, dasyprocta, cebus, albury, abet, hbox, amalthea, ursus,
# Nearest to four: five, six, three, eight, seven, two, nine, zero,
# Nearest to zero: eight, five, six, seven, nine, four, three, circ,
# Average loss at step  72000 :  4.75266147339344
# Average loss at step  74000 :  4.806672734975815
# Average loss at step  76000 :  4.7327971005439755
# Average loss at step  78000 :  4.803847678929567
# Average loss at step  80000 :  4.809508691310882
# Nearest to this: which, it, that, the, morita, circ, another, one,
# Nearest to such: well, these, alcohols, known, many, priority, calculi, nouveau,
# Nearest to on: in, upon, during, from, at, dasyprocta, meridians, fao,
# Nearest to an: terminal, carolla, quelled, voted, aveiro, taxis, replicas, dasyprocta,
# Nearest to will: would, can, may, could, might, should, looters, must,
# Nearest to i: chefs, UNK, you, who, jp, thaler, ursus, mouvement,
# Nearest to was: is, were, has, had, when, by, became, does,
# Nearest to at: in, on, during, circ, mukherjee, agouti, for, dasyprocta,
# Nearest to state: garrisoned, cebus, airtight, archie, circ, ursus, monroe, afghan,
# Nearest to had: has, have, was, were, aquarius, mico, djs, been,
# Nearest to three: five, four, two, six, seven, eight, one, circ,
# Nearest to no: hbox, neman, it, a, daimler, campy, flooding, pulau,
# Nearest to into: from, albury, through, with, under, within, in, birkenau,
# Nearest to as: vma, dasyprocta, hbox, cebus, abet, albury, amalthea, ursus,
# Nearest to four: five, six, seven, three, eight, two, zero, nine,
# Nearest to zero: five, six, four, eight, seven, nine, circ, three,
# Average loss at step  82000 :  4.771772687673569
# Average loss at step  84000 :  4.758917813062668
# Average loss at step  86000 :  4.772461634993554
# Average loss at step  88000 :  4.728953944444656
# Average loss at step  90000 :  4.71741794347763
# Nearest to this: it, which, the, that, another, circ, morita, some,
# Nearest to such: well, these, alcohols, known, priority, many, calculi, nouveau,
# Nearest to on: in, upon, during, from, dasyprocta, fao, at, meridians,
# Nearest to an: quelled, carolla, terminal, voted, taxis, replicas, cogito, the,
# Nearest to will: would, can, could, may, might, should, must, looters,
# Nearest to i: you, chlamydia, chefs, UNK, who, jp, ursus, thaler,
# Nearest to was: is, were, has, had, became, by, when, be,
# Nearest to at: in, agouti, during, circ, six, mukherjee, dasyprocta, on,
# Nearest to state: garrisoned, cebus, circ, archie, ursus, airtight, microcebus, monroe,
# Nearest to had: has, have, was, were, aquarius, mico, thaler, agouti,
# Nearest to three: five, four, two, six, seven, eight, one, nine,
# Nearest to no: hbox, a, neman, it, flooding, shown, pulau, daimler,
# Nearest to into: from, through, albury, with, within, under, on, birkenau,
# Nearest to as: vma, abet, dasyprocta, cebus, by, hbox, albury, when,
# Nearest to four: five, seven, three, six, eight, two, one, nine,
# Nearest to zero: five, eight, seven, six, nine, four, circ, three,
# Average loss at step  92000 :  4.663646671533584
# Average loss at step  94000 :  4.721747888565064
# Average loss at step  96000 :  4.677650302767754
# Average loss at step  98000 :  4.584157465219498
# Average loss at step  100000 :  4.695225720763206
# Nearest to this: it, which, the, that, circ, another, some, morita,
# Nearest to such: well, these, known, alcohols, many, priority, calculi, endo,
# Nearest to on: in, upon, during, from, dasyprocta, through, at, fao,
# Nearest to an: terminal, voted, carolla, quelled, taxis, aveiro, cogito, hairstyle,
# Nearest to will: would, can, could, may, might, should, must, to,
# Nearest to i: you, chlamydia, chefs, UNK, thaler, ursus, jp, who,
# Nearest to was: is, were, had, has, became, when, by, be,
# Nearest to at: in, during, circ, mukherjee, agouti, dasyprocta, on, trolls,
# Nearest to state: garrisoned, cebus, city, ursus, circ, county, airtight, archie,
# Nearest to had: has, have, was, were, mico, agouti, aquarius, thaler,
# Nearest to three: five, four, seven, two, six, eight, nine, circ,
# Nearest to no: hbox, a, neman, pulau, alicante, difranco, daimler, it,
# Nearest to into: from, through, albury, with, within, under, birkenau, on,
# Nearest to as: vma, dasyprocta, cebus, abet, hbox, albury, amalthea, ursus,
# Nearest to four: five, seven, three, six, eight, two, zero, nine,
# Nearest to zero: eight, five, nine, seven, six, four, microcebus, circ,

# %%
def plot_with_labels(low_dim_embs, labels, filename):
  assert low_dim_embs.shape[0] >= len(labels), 'More labels than embeddings'
  plt.figure(figsize=(18, 18))  # in inches
  for i, label in enumerate(labels):
    x, y = low_dim_embs[i, :]
    plt.scatter(x, y)
    plt.annotate(label,
                 xy=(x, y),
                 xytext=(5, 2),
                 textcoords='offset points',
                 ha='right',
                 va='bottom')

  plt.savefig(filename)


# pylint: disable=g-import-not-at-top
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
plot_only = 500
low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
labels = [reverse_dictionary[i] for i in xrange(plot_only)]
plot_with_labels(low_dim_embs, labels, os.path.join(gettempdir(), 'tsne.png'))
